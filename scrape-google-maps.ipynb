# %%
# %pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (4.9.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import warnings
import time 
import string
# import openpyxl
import os

warnings.filterwarnings("ignore")

# %%
import pandas as pd
pd.reset_option('display.max_row', None)

# %%
df_jakarta = pd.read_csv('jakarta.csv')
df_jakarta
# Out:
#      tahun         nama_provinsi      nama_kabupaten   nama_kecamatan  \
# 0     2015  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2015  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2015  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2015  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2015  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2015  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2015  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2015  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2015  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2015  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      nama_kelurahan  luas_wilayah_(km2)  kepadatan_(jiwa/km2)  Unnamed: 7  \
# 0       P. PANGGANG                0.62              10278.58         NaN
# 1         P. KELAPA                2.58               2539.95         NaN
# 2        P. HARAPAN                2.45                962.32         NaN
# 3    P. UNTUNG JAWA                1.03               2191.54         NaN
# 4         P. TIDUNG                1.07               4714.69         NaN
# ..              ...                 ...                   ...         ...
# 262          MUNJUL                1.90              13493.96         NaN
# 263            SETU                3.25               6467.46         NaN
# 264      BAMBU APUS                3.17               8818.40         NaN
# 265    LUBANG BUAYA                3.72              18750.94         NaN
# 266           CEGER                3.63               5626.03         NaN
#
#      Unnamed: 8  Unnamed: 9  ...  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# 0           NaN         NaN  ...          NaN          NaN          NaN
# 1           NaN         NaN  ...          NaN          NaN          NaN
# 2           NaN         NaN  ...          NaN          NaN          NaN
# 3           NaN         NaN  ...          NaN          NaN          NaN
# 4           NaN         NaN  ...          NaN          NaN          NaN
# ..          ...         ...  ...          ...          ...          ...
# 262         NaN         NaN  ...          NaN          NaN          NaN
# 263         NaN         NaN  ...          NaN          NaN          NaN
# 264         NaN         NaN  ...          NaN          NaN          NaN
# 265         NaN         NaN  ...          NaN          NaN          NaN
# 266         NaN         NaN  ...          NaN          NaN          NaN
#
#      Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 262          NaN          NaN          NaN          NaN          NaN
# 263          NaN          NaN          NaN          NaN          NaN
# 264          NaN          NaN          NaN          NaN          NaN
# 265          NaN          NaN          NaN          NaN          NaN
# 266          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 33  Unnamed: 34
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 262          NaN          NaN
# 263          NaN          NaN
# 264          NaN          NaN
# 265          NaN          NaN
# 266          NaN          NaN
#
# [267 rows x 35 columns]

# %%
df_jakarta = df_jakarta[{'nama_kabupaten', 'nama_kecamatan', 'nama_kelurahan', 'luas_wilayah_(km2)', 'kepadatan_(jiwa/km2)'}]
df_jakarta
# Out:
#      nama_kelurahan  luas_wilayah_(km2)  kepadatan_(jiwa/km2)  \
# 0       P. PANGGANG                0.62              10278.58
# 1         P. KELAPA                2.58               2539.95
# 2        P. HARAPAN                2.45                962.32
# 3    P. UNTUNG JAWA                1.03               2191.54
# 4         P. TIDUNG                1.07               4714.69
# ..              ...                 ...                   ...
# 262          MUNJUL                1.90              13493.96
# 263            SETU                3.25               6467.46
# 264      BAMBU APUS                3.17               8818.40
# 265    LUBANG BUAYA                3.72              18750.94
# 266           CEGER                3.63               5626.03
#
#       nama_kecamatan      nama_kabupaten
# 0    KEP. SERIBU UTR  KAB.ADM.KEP.SERIBU
# 1    KEP. SERIBU UTR  KAB.ADM.KEP.SERIBU
# 2    KEP. SERIBU UTR  KAB.ADM.KEP.SERIBU
# 3    KEP. SERIBU SLT  KAB.ADM.KEP.SERIBU
# 4    KEP. SERIBU SLT  KAB.ADM.KEP.SERIBU
# ..               ...                 ...
# 262         CIPAYUNG       JAKARTA TIMUR
# 263         CIPAYUNG       JAKARTA TIMUR
# 264         CIPAYUNG       JAKARTA TIMUR
# 265         CIPAYUNG       JAKARTA TIMUR
# 266         CIPAYUNG       JAKARTA TIMUR
#
# [267 rows x 5 columns]

# %%
df_jakarta_new = df_jakarta.copy()

# %%
df_jakarta_new['nama_kelurahan'] = df_jakarta['nama_kelurahan'].str.replace("P. ", "PULAU ")

# %%
df_jakarta_new['nama_kecamatan'] = df_jakarta_new['nama_kecamatan'].str.replace("UTR", "UTARA")
df_jakarta_new['nama_kecamatan'] = df_jakarta_new['nama_kecamatan'].str.replace("SLT", "SELATAN")

# %%
df_jakarta_new['nama_kecamatan'] = df_jakarta_new['nama_kecamatan'].str.replace("KELAPULAU", "KELAPA")
df_jakarta_new['nama_kecamatan'] = df_jakarta_new['nama_kecamatan'].str.replace("KALI DERES", "KALIDERES")

# %%
df_jakarta_new = df_jakarta_new[df_jakarta_new['nama_kelurahan'] != "KAMAL"]

# %%
import re
def search_word(text, word, type):
    if (type == "address"): 
        words = text.split(sep=', ')  # Split the text into individual words
    elif (type == "name"):
        words = re.split(r"[', ']", text)
    
    count = 0
    value = False
    # print(words)
    
    for w in words:
        if w == word:
            count+=1
            value = True  # Word found
    return value, count # Word not found

# %%
maps_df = pd.DataFrame()

# %%
def scratch_data (maps_df, jenis, kelurahan, kecamatan): 
    driver.switch_to.default_content()
    searchbox=driver.find_element(By.ID, ('searchboxinput'))

    if (kelurahan == kecamatan): 
        location= f"kelurahan {kelurahan} kecamatan {kecamatan}"
    else: 
        location= f"{kelurahan} {kecamatan}"

    searchbox.send_keys(location)
    searchbox.send_keys(Keys.ENTER)
    time.sleep(2)

    try: 
        kelurahan = driver.find_element(By.CSS_SELECTOR, "[class*=fontHeadlineLarge]").text
        time.sleep(2)
    except NoSuchElementException:
        pass

    searchbox.send_keys(f" {jenis}")
    searchbox.send_keys(Keys.ENTER)
    time.sleep(3)

    sidebar = driver.find_element(By.XPATH, "//*[@role='feed']")

    # Scroll until the desired text is visible
    i = 0
    while True and i <= 5:
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight;", sidebar)
        i += 1
        
        try:
            end_text_element = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, '//*[contains(text(), "Anda telah mencapai akhir daftar")]')))
            break  # Break the loop if the text is found
        except:
            pass  # Continue scrolling if the text is not found

    entries = driver.find_elements(By.XPATH, "//*[@role='article']")

    for entry in entries:
        name= entry.get_attribute("aria-label")

        if (search_word(name.upper(), jenis.upper(), "name")[0]): 
            link = entry.find_element(By.TAG_NAME, "a")
            
            driver.execute_script("arguments[0].scrollIntoView(true);", link)
            link.click()
            time.sleep(3)

            # Switch to the pop-up window
            for window_handle in driver.window_handles:
                if window_handle != driver.current_window_handle:
                    driver.switch_to.window(window_handle)
                    break

            # driver.switch_to.window(link)
            try: 
                address = driver.find_element(By.CSS_SELECTOR, '[data-item-id = "address"]').get_attribute("aria-label")

            except NoSuchElementException:
                continue
            
            if (kelurahan != kecamatan): 
                if (search_word(address, kelurahan, "address")[0]): 
                    # print(name)
                    # print(address)
                    maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama Starbucks': name, 'Alamat' : address}, ignore_index= True)
            else:
                if (search_word(address, kelurahan, "address")[0]):
                    if (search_word(address, kelurahan, "address")[1] > 1): 
                        maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama Starbucks': name, 'Alamat' : address}, ignore_index= True)
        else: continue
    
    searchbox.clear()
    return maps_df

# %%
i = 0

# %%
from selenium.common.exceptions import StaleElementReferenceException
#Loading Selenium Webdriver 
driver= webdriver.Chrome()
wait = WebDriverWait(driver, 5)
 
#Opening Google maps 
driver.get("https://www.google.com/maps")
time.sleep(3)

for index, row in df_jakarta_new.iterrows():
    try: 
        if (index >= i): 
            i = index
            maps_df = scratch_data(maps_df, "Starbucks", row["nama_kelurahan"], row["nama_kecamatan"])
    except StaleElementReferenceException:
        if (index >= i): 
            i = index
            maps_df = scratch_data(maps_df, "Starbucks", row["nama_kelurahan"], row["nama_kecamatan"])

# %%
maps_df
# Out:
#                  Kelurahan    Kecamatan  \
# 0              Petojo Sel.       GAMBIR
# 1              Petojo Sel.       GAMBIR
# 2                 Kb. Klp.       GAMBIR
# 3         Gn. Sahari Utara  SAWAH BESAR
# 4          Mangga Dua Sel.  SAWAH BESAR
# ..                     ...          ...
# 144  Halim Perdana Kusumah      MAKASAR
# 145  Halim Perdana Kusumah      MAKASAR
# 146               Cipayung     CIPAYUNG
# 147                  Ceger     CIPAYUNG
# 148                  Ceger     CIPAYUNG
#
#                                      Nama Starbucks  \
# 0                                  Starbucks Cideng
# 1                                   Starbucks Ba'Be
# 2                          Starbucks DT Hayam Wuruk
# 3                    Starbucks - Royalton Kemayoran
# 4                               Starbucks RS Husada
# ..                                              ...
# 144            Starbucks Gate 8 Halim Perdanakusuma
# 145  Starbucks Coffee - Halim Perdanakusuma Airport
# 146                                Starbucks Coffee
# 147                         Starbucks Green Terrace
# 148                    Starbucks Sakura Garden City
#
#                                                 Alamat
# 0    Alamat: RRF6+VV4, Jl. Cideng Timur, RT.4/RW.6,...
# 1    Alamat: RRC9+MG2, RT.4/RW.3, Petojo Sel., Keca...
# 2    Alamat: Jl. Hayam Wuruk No.8, RT.6/RW.2, Kb. K...
# 3    Alamat: RRXR+P7V, Jl. Industri Raya, RT.1/RW.7...
# 4    Alamat: Jl. Raya Mangga Besar No.1, RW.1, Mang...
# ..                                                 ...
# 144  Alamat: PVMP+Q7H, Halim Perdana Kusumah, Kec. ...
# 145  Alamat: Jl. Komodor Halim Perdana Kusuma No.15...
# 146  Alamat: Km. 10.6, Cibubur Square 1st Fl Zona B...
# 147  Alamat: Jl. Raya Mabes Hankam, Ceger, Kec. Cip...
# 148  Alamat: MVGQ+MHJ, Jl. Bina Marga, Ceger, Kec. ...
#
# [149 rows x 4 columns]

# %%
maps_df.to_csv("Starbucks di Jakarta Versi New.csv")

# %% [markdown]
# # Universitas / Sekolah Tinggi

# %%
def search_word_list(text, word_list, type):
    if (type == "address"): 
        words = text.split(sep=', ')  # Split the text into individual words
    elif (type == "name"):
        words = re.split(r"[', ']", text)
    
    count = 0
    value = False
    # print(words)
    
    for word in word_list: 
        for w in words:
            if w == word:
                count+=1
                value = True  # Word found
    return value, count # Word not found

# %%
def scratch_data_list (maps_df, jenis, kelurahan, kecamatan, kategori): 
    driver.switch_to.default_content()
    searchbox=driver.find_element(By.ID, ('searchboxinput'))

    if (kelurahan == kecamatan): 
        location= f"kelurahan {kelurahan} kecamatan {kecamatan}"
    else: 
        location= f"{kelurahan} {kecamatan}"

    searchbox.send_keys(location)
    searchbox.send_keys(Keys.ENTER)
    time.sleep(2)

    try: 
        kelurahan_new = driver.find_element(By.CSS_SELECTOR, "[class*=fontHeadlineLarge]").text
        time.sleep(2)
    except NoSuchElementException:
        pass

    searchbox.send_keys(f" {jenis}")
    searchbox.send_keys(Keys.ENTER)
    time.sleep(3)

    sidebar = driver.find_element(By.XPATH, "//*[@role='feed']")

    # Scroll until the desired text is visible
    i = 0
    while True and i <= 7:
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight;", sidebar)
        i += 1
        
        try:
            end_text_element = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, '//*[contains(text(), "Anda telah mencapai akhir daftar")]')))
            break  # Break the loop if the text is found
        except:
            pass  # Continue scrolling if the text is not found

    entries = driver.find_elements(By.XPATH, "//*[@role='article']")
    kategori_upper = [kat.upper() for kat in kategori] 

    for entry in entries:
        name= entry.get_attribute("aria-label")

        if (name != kelurahan):

            link = entry.find_element(By.TAG_NAME, "a")
            
            driver.execute_script("arguments[0].scrollIntoView(true);", link)
            link.click()
            time.sleep(3)

            # Switch to the pop-up window
            for window_handle in driver.window_handles:
                if window_handle != driver.current_window_handle:
                    driver.switch_to.window(window_handle)
                    break
            
            try: 
                category = driver.find_element(By.CSS_SELECTOR, "[jsaction = 'pane.rating.category']").text
            except NoSuchElementException:
                continue
            if (search_word_list(category.upper(), kategori_upper, "name")[0]): 
                # driver.switch_to.window(link)
                print("Berhasil")
                try: 
                    address = driver.find_element(By.CSS_SELECTOR, '[data-item-id = "address"]').get_attribute("aria-label")

                except NoSuchElementException:
                    continue
                
                if (kelurahan_new != kecamatan): 
                    if (search_word(address, kelurahan_new, "address")[0]): 
                        # print(name)
                        # print(address)
                        maps_df = maps_df.append({'Kelurahan': kelurahan_new, 'Kecamatan': kecamatan, 'Nama Starbucks': name, 'Alamat' : address}, ignore_index= True)
                        print("Data Ditambahkan")
                else:
                    if (search_word(address, kelurahan_new, "address")[0]):
                        if (search_word(address, kelurahan_new, "address")[1] > 1): 
                            maps_df = maps_df.append({'Kelurahan': kelurahan_new, 'Kecamatan': kecamatan, 'Nama Starbucks': name, 'Alamat' : address}, ignore_index= True)
            else: continue
    
    searchbox.clear()
    return maps_df

# %%
univ_df = pd.DataFrame()
i = 0

# %%
from selenium.common.exceptions import StaleElementReferenceException, ElementNotInteractableException
#Loading Selenium Webdriver 
driver= webdriver.Chrome()
wait = WebDriverWait(driver, 5)
 
#Opening Google maps 
driver.get("https://www.google.com/maps")
time.sleep(3)

category = ["Universitas", "Perguruan"]

for index, row in df_jakarta_new.iterrows():
    try: 
        if (index >= i): 
            i = index
            univ_df = scratch_data_list(univ_df, "Universitas", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except StaleElementReferenceException:
        if (index >= i): 
            i = index
            univ_df = scratch_data_list(univ_df, "Universitas", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except NoSuchElementException: 
        continue
    except ElementNotInteractableException:
        pass

i = 0
# Out:
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil

# %%
univ_df
# Out:
#     Kelurahan Kecamatan                                  Nama Starbucks  \
# 0      Gambir    GAMBIR                                           Yayan
# 1      Cideng    GAMBIR     Universitas Budi Luhur Kampus Unit Roxy Mas
# 2      Cideng    GAMBIR                Universitas INABA Kampus Jakarta
# 3      Cideng    GAMBIR                         STIH PROF GAYUS LUMBUUN
# 4      Cideng    GAMBIR                 Fakultas Ilmu Keperawatan roxy.
# ..        ...       ...                                             ...
# 494   Cibubur   CIRACAS  Sekolah Tinggi Ilmu Kesehatan Mitra RIA Husada
# 495   Susukan   CIRACAS                              UNIVERSITAS IPWIJA
# 496   Susukan   CIRACAS                                       Pak Idrus
# 497   Susukan   CIRACAS                                Stikes Jayakarta
# 498   Susukan   CIRACAS                       Akademi Farmasi Mahadhika
#
#                                                 Alamat
# 0    Alamat: RR9H+Q9R, Gambir, Kecamatan Gambir, Ko...
# 1    Alamat: Pusat Niaga Roxy Mas, Jl. KH. Hasyim A...
# 2    Alamat: Jl. Siantar No.6, RW.3, Cideng, Kecama...
# 3    Alamat: Jl. Talaud Jl. Biak No.1A, RT.10/RW.4,...
# 4    Alamat: Asy'ari, Jl. KH. Hasyim Ashari No.8, R...
# ..                                                 ...
# 494  Alamat: Jl. Karya Bakti No.3, RT.8/RW.7, Cibub...
# 495  Alamat: 16, Jl. H. Baping No.17, RT.10/RW.6, S...
# 496  Alamat: Jl. Asmin No.56, RT.8/RW.3, Susukan, K...
# 497  Alamat: Jl. H. Baping No.4, RT.8/RW.6, Susukan...
# 498  Alamat: Jl. Suci No.9A, RT.1/RW.4, Susukan, Ke...
#
# [499 rows x 4 columns]

# %%
univ_df.to_csv("Universitas di Jakarta.csv", index = False)

# %%
# kalo dah beda hari pas nge-run
univ_df.to_csv("Universitas di Jakarta.csv", mode = "a", header = False, index = False)

# %% [markdown]
# # SMA

# %%
def scratch_data_list_2 (maps_df, jenis, kelurahan, kecamatan, kategori, ketentuan): 
    driver.switch_to.default_content()
    searchbox=driver.find_element(By.ID, ('searchboxinput'))

    if (kelurahan == kecamatan): 
        location= f"kelurahan {kelurahan} kecamatan {kecamatan}"
    else: 
        location= f"{kelurahan} {kecamatan}"

    searchbox.send_keys(location)
    searchbox.send_keys(Keys.ENTER)
    time.sleep(2)

    try: 
        kelurahan = driver.find_element(By.CSS_SELECTOR, "[class*=fontHeadlineLarge]").text
        time.sleep(2)
    except NoSuchElementException:
        pass

    searchbox.send_keys(f" {jenis}")
    searchbox.send_keys(Keys.ENTER)
    time.sleep(3)

    sidebar = driver.find_element(By.XPATH, "//*[@role='feed']")

    # Scroll until the desired text is visible
    i = 0
    while True and i <= 7:
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight;", sidebar)
        i += 1
        
        try:
            end_text_element = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, '//*[contains(text(), "Anda telah mencapai akhir daftar")]')))
            break  # Break the loop if the text is found
        except:
            pass  # Continue scrolling if the text is not found

    entries = driver.find_elements(By.XPATH, "//*[@role='article']")
    kategori_upper = [kat.upper() for kat in kategori] 
    ketentuan_upper = [ket.upper() for ket in ketentuan]

    for entry in entries:
        name= entry.get_attribute("aria-label")

        if (name != kelurahan):

            link = entry.find_element(By.TAG_NAME, "a")
            
            driver.execute_script("arguments[0].scrollIntoView(true);", link)
            link.click()
            time.sleep(3)

            # Switch to the pop-up window
            for window_handle in driver.window_handles:
                if window_handle != driver.current_window_handle:
                    driver.switch_to.window(window_handle)
                    break
            
            try: 
                category = driver.find_element(By.CSS_SELECTOR, "[jsaction = 'pane.rating.category']").text
            except NoSuchElementException:
                continue

            if ((search_word_list(category.upper(), kategori_upper, "name")[0]) or search_word_list(name.upper(), ketentuan_upper, "name")[0]): 
                # driver.switch_to.window(link)
                print("Berhasil")
                try: 
                    address = driver.find_element(By.CSS_SELECTOR, '[data-item-id = "address"]').get_attribute("aria-label")

                except NoSuchElementException:
                    continue
                
                if (kelurahan != kecamatan): 
                    if (kelurahan.split(", ")) == 1:
                        if (search_word(address.upper(), kelurahan.upper(), "address")[0]): 
                            maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama SMA': name, 'Alamat' : address}, ignore_index= True)
                            print("Data Ditambahkan")
                    else:
                        if (search_word(address.upper(), kelurahan.split(", ")[0].upper(), "address")[0]): 
                            maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama SMA': name, 'Alamat' : address}, ignore_index= True)
                            print("Data Ditambahkan")
                else:
                    if (search_word(address.upper(), kelurahan.upper(), "address")[0]):
                        if (search_word(address.upper(), kelurahan.upper(), "address")[1] > 1): 
                            maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama SMA': name, 'Alamat' : address}, ignore_index= True)
            else: continue
    
    searchbox.clear()
    return maps_df

# %%
sma_df = pd.DataFrame()
i = 0

# %%
from selenium.common.exceptions import StaleElementReferenceException, ElementNotInteractableException
#Loading Selenium Webdriver 
driver= webdriver.Chrome()
wait = WebDriverWait(driver, 5)
 
#Opening Google maps 
driver.get("https://www.google.com/maps")
time.sleep(3)

category = ["Sekolah Menengah Atas", "Atas", "Umum", "Kejuruan"]
keterangan = ["SMA", "SMAN", "MA", "MAN", "SMK", "SMKN", "SMU", "SMAK", "ATAS"]

for index, row in df_jakarta_new.iterrows():
    try: 
        if (index >= i): 
            i = index
            sma_df = scratch_data_list_2(sma_df, "Sekolah Menengah Atas", row["nama_kelurahan"], row["nama_kecamatan"], category, keterangan)
    except StaleElementReferenceException:
        if (index >= i): 
            i = index
            sma_df = scratch_data_list_2(sma_df, "Sekolah Menengah Atas", row["nama_kelurahan"], row["nama_kecamatan"], category, keterangan)
    except NoSuchElementException: 
        continue
    except ElementNotInteractableException:
        if (index >= i): 
            i = index
            sma_df = scratch_data_list_2(sma_df, "Sekolah Menengah Atas", row["nama_kelurahan"], row["nama_kecamatan"], category, keterangan)
    # finally:
    #     searchbox=driver.find_element(By.ID, ('searchboxinput'))
    #     searchbox.clear() 
    #     continue

i = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 17
#      15     if (index >= i):
#      16         i = index
# ---> 17         sma_df = scratch_data_list_2(sma_df, "Sekolah Menengah Atas", row["nama_kelurahan"], row["nama_kecamatan"], category, keterangan)
#      18 except StaleElementReferenceException:
#      19     if (index >= i):
#
# NameError: name 'scratch_data_list_2' is not defined

# %%
sma_df
# Out:
#                                              Kelurahan            Kecamatan  \
# 0    Pulau Panggang, Kepulauan Seribu Utara, Kepula...    KEP. SERIBU UTARA
# 1                                         Pulau Tidung  KEP. SERIBU SELATAN
# 2                                         Pulau Tidung  KEP. SERIBU SELATAN
# 3                                               Gambir               GAMBIR
# 4                                         Petojo Utara               GAMBIR
# ..                                                 ...                  ...
# 458                                         Bambu Apus             CIPAYUNG
# 459                                       Lubang Buaya             CIPAYUNG
# 460                                       Lubang Buaya             CIPAYUNG
# 461                                       Lubang Buaya             CIPAYUNG
# 462                                       Lubang Buaya             CIPAYUNG
#
#                                        Nama SMA  \
# 0        SMA NEGERI 69 JAKARTA Kepulauan Seribu
# 1                SMK NEGERI 61 Kepulauan Seribu
# 2                        ASRAMA SMKN 61 JAKARTA
# 3                          SMA Negeri 4 Jakarta
# 4                               SMAN 25 Jakarta
# ..                                          ...
# 458         Nizamia Andalusia High School (NHS)
# 459  Sekolah Menengah Kejuruan Islam Al-Makiyah
# 460                            SMAN 113 Jakarta
# 461                                 SMA PGRI 24
# 462    Sekolah Menengah Kejuruan Jakarta Raya 2
#
#                                                 Alamat
# 0    Alamat: 7J27+X95, Pulau Panggang, Kepulauan Se...
# 1    Alamat: 5GX5+4Q8, Pulau Tidung, Kec. Kepulauan...
# 2    Alamat: JLN PANTAI SELATAN No.1, Pulau Tidung,...
# 3    Alamat: Jl. Batu III No.3, RT.7/RW.1, Gambir, ...
# 4    Alamat: Jalan A.M Sangaji No. 22-24 Petojo Uta...
# ..                                                 ...
# 458  Alamat: Jl. Raya Mabes Hankam No.100, RT.2/RW....
# 459  Alamat: Jl. Gorda No.RT01/01, Lubang Buaya, Ke...
# 460  Alamat: Jl. Al.Baidho I No.10, RT.10/RW.9, Lub...
# 461  Alamat: Jalan SMPN 157 No.33, RT.2/RW.6, Luban...
# 462  Alamat: Jl. Raya Pd. Gede No.36, RT.11/RW.1, L...
#
# [463 rows x 4 columns]

# %%
sma_df.to_csv("SMA di Jakarta.csv", index = False)

# %%
# kalo mau append -> ini kalo udah beda hari nanti pakenya ini pas mau lanjut nge-run
sma_df.to_csv("SMA di Jakarta.csv", mode="a", header = False, index = False)

# %% [markdown]
# # Tempat Perbelanjaan

# %%
def scratch_data_list_shop (maps_df, jenis, kelurahan, kecamatan, kategori): 
    driver.switch_to.default_content()
    searchbox=driver.find_element(By.ID, ('searchboxinput'))

    if (kelurahan == kecamatan): 
        location= f"kelurahan {kelurahan} kecamatan {kecamatan}"
    else: 
        location= f"{kelurahan} {kecamatan}"

    searchbox.send_keys(location)
    searchbox.send_keys(Keys.ENTER)
    time.sleep(2)

    try: 
        kelurahan = driver.find_element(By.CSS_SELECTOR, "[class*=fontHeadlineLarge]").text
        time.sleep(2)
    except NoSuchElementException:
        pass

    searchbox.send_keys(f" {jenis}")
    searchbox.send_keys(Keys.ENTER)
    time.sleep(3)

    sidebar = driver.find_element(By.XPATH, "//*[@role='feed']")

    # Scroll until the desired text is visible
    i = 0
    while True and i <= 7:
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight;", sidebar)
        i += 1
        
        try:
            end_text_element = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, '//*[contains(text(), "Anda telah mencapai akhir daftar")]')))
            break  # Break the loop if the text is found
        except:
            pass  # Continue scrolling if the text is not found
    
    entries = driver.find_elements(By.XPATH, "//*[@role='article']")
    kategori_upper = [kat.upper() for kat in kategori] 
    
    # Continue with other operations on the page if needed
    for entry in entries:
        name= entry.get_attribute("aria-label")

        if (name != kelurahan):

            link = entry.find_element(By.TAG_NAME, "a")
            
            driver.execute_script("arguments[0].scrollIntoView(true);", link)
            link.click()
            time.sleep(3)

            # Switch to the pop-up window
            for window_handle in driver.window_handles:
                if window_handle != driver.current_window_handle:
                    driver.switch_to.window(window_handle)
                    break
            
            try: 
                category = driver.find_element(By.CSS_SELECTOR, "[jsaction = 'pane.rating.category']").text
            except NoSuchElementException:
                continue

            if (search_word_list(category.upper(), kategori_upper, "name")[0] and (search_word(name, "Bintang", "name")[0] == False)): #or search_word_list(name.upper(), ketentuan_upper, "name")[0]): 
                # driver.switch_to.window(link)
                print("Berhasil")
                if (name != "88Bintang Perdana II"): 
                    try: 
                        rating = entry.find_element(By.CSS_SELECTOR, "[aria-label*='Bintang ']").text
                        print(rating)
                    except NoSuchElementException:
                        rating = "0,0"
                        continue
                    
                    if (float(rating[:2].replace(",", ".")) > 3.0): 
                        try: 
                            address = driver.find_element(By.CSS_SELECTOR, '[data-item-id = "address"]').get_attribute("aria-label")

                        except NoSuchElementException:
                            continue
                        
                        if (kelurahan != kecamatan): 
                            if (kelurahan.split(", ")) == 1:
                                if (search_word(address.upper(), kelurahan.upper(), "address")[0]): 
                                    maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama': name, 'Alamat' : address}, ignore_index= True)
                                    print("Data Ditambahkan")
                            else:
                                if (search_word(address.upper(), kelurahan.split(", ")[0].upper(), "address")[0]): 
                                    maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama': name, 'Alamat' : address}, ignore_index= True)
                                    print("Data Ditambahkan")
                        else:
                            if (search_word(address.upper(), kelurahan.upper(), "address")[0]):
                                if (search_word(address.upper(), kelurahan.upper(), "address")[1] > 1): 
                                    maps_df = maps_df.append({'Kelurahan': kelurahan, 'Kecamatan': kecamatan, 'Nama': name, 'Alamat' : address}, ignore_index= True)
                                    print("Data Ditambahkan")
                    rating = "0,0"
            else: continue
    
    searchbox.clear()
    return maps_df

# %%
i = 0
toko_df = pd.DataFrame()

# %%
from selenium.common.exceptions import StaleElementReferenceException, ElementNotInteractableException
#Loading Selenium Webdriver 
driver= webdriver.Chrome()
wait = WebDriverWait(driver, 5)
 
#Opening Google maps 
driver.get("https://www.google.com/maps")
time.sleep(3)

category = ["Pusat Perbelanjaan", "Perbelanjaan", "Toko"]

for index, row in df_jakarta_new.iterrows():
    try: 
        if (index >= i): 
            i = index
            toko_df = scratch_data_list_shop(toko_df, "Pusat Perbelanjaan", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except StaleElementReferenceException:
        if (index >= i): 
            i = index
            toko_df = scratch_data_list_shop(toko_df, "Pusat Perbelanjaan", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except NoSuchElementException: 
        continue
    except ElementNotInteractableException:
        pass
    # finally:
    #     searchbox=driver.find_element(By.ID, ('searchboxinput'))
    #     searchbox.clear() 
    #     continue

i = 0
# Out:
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# 3,5(2)
# Berhasil
# 4,8(4)
# Data Ditambahkan
# Berhasil
# 5,0(6)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# 4,0(3)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(3)
# Berhasil
# 5,0(3)
# Berhasil
# 5,0(2)
# Berhasil
# 3,0(1)
# Berhasil
# 5,0(4)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 4,6(2.901)
# Data Ditambahkan
# Berhasil
# 5,0(2)
# Berhasil
# Berhasil
# 4,0(2)
# Berhasil
# Berhasil
# Berhasil
# 4,5(4)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# 5,0(2)
# Berhasil
# Berhasil
# 5,0(3)
# Berhasil
# Berhasil
# 5,0(17)
# Data Ditambahkan
# Berhasil
# 5,0(4)
# Berhasil
# 4,6(18)
# Berhasil
# 5,0(2)
# Berhasil
# 5,0(3)
# Berhasil
# 4,5(6)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,7(3)
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(2)
# Berhasil
# 3,0(1)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# 4,6(24)
# Berhasil
# 5,0(12)
# Berhasil
# 5,0(3)
# Berhasil
# 5,0(2)
# Berhasil
# Berhasil
# 5,0(5)
# Berhasil
# 4,7(3)
# Berhasil
# Berhasil
# 5,0(3)
# Berhasil
# 4,3(6)
# Berhasil
# 5,0(2)
# Berhasil
# Berhasil
# 4,6(8)
# Berhasil
# Berhasil
# 4,5(4)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# 5,0(12)
# Berhasil
# Berhasil
# 4,5(145)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 4,7(6)
# Berhasil
# 4,1(8)
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# 4,6(6.630)
# Berhasil
# 4,4(10)
# Berhasil
# 4,8(19)
# Berhasil
# Berhasil
# 4,5(2)
# Berhasil
# 4,7(3)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 4,0(1)
# Berhasil
# 5,0(6)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 4,9(17)
# Berhasil
# 4,2(5)
# Data Ditambahkan
# Berhasil
# 4,0(1)
# Berhasil
# 5,0(38)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,0(5)
# Berhasil
# Berhasil
# Berhasil

# %%
toko_df
# Out:
#        Kelurahan     Kecamatan                                     Nama  \
# 0     Ps. Minggu  PASAR MINGGU                    Toko mirabusana jahit
# 1     Ps. Minggu  PASAR MINGGU  Manja Acc Pasar Minggu Agen Mainan &Acc
# 2     Ps. Minggu  PASAR MINGGU                               Toko Shaga
# 3     Ps. Minggu  PASAR MINGGU                             Toko.Barokah
# 4     Ps. Minggu  PASAR MINGGU                     Pejaten Village Mall
# ...          ...           ...                                      ...
# 2346       Ceger      CIPAYUNG                       Green Terrace TMII
# 2347       Ceger      CIPAYUNG               KEDAI PRAMUKA ALFATH SCOUT
# 2348       Ceger      CIPAYUNG                   Kios souvenir ibu yati
# 2349       Ceger      CIPAYUNG                      Toko Layangan Cakra
# 2350       Ceger      CIPAYUNG          MR BEE SPEED AUTOMOTIVE MACHINE
#
#                                                  Alamat
# 0     Alamat: Pasar Minggu Lantai 1 Los BB # 11, Jl....
# 1     Alamat: Jl. Masjid Al-Makmuriyah No.12, RT.1/R...
# 2     Alamat: Pejaten village mall, LG floor #19A, R...
# 3     Alamat: Jl. Gurame Raya No.1, RT.3/RW.9, Jati ...
# 4     Alamat: Jl. Warung Jati Barat No.39, RW.5, Jat...
# ...                                                 ...
# 2346  Alamat: MVWP+6R5, Jl. Raya Mabes Hankam, Ceger...
# 2347  Alamat: Jl. SMP 160 No.71, RW.5, Ceger, Kec. C...
# 2348  Alamat: MWX2+HRH, Ceger, Kec. Cipayung, Kota J...
# 2349  Alamat: Jl. Maja No.12, RT.5/RW.5, Ceger, Kec....
# 2350  Alamat: Jl hankam raya No.37, RT.1/RW.2, Ceger...
#
# [2351 rows x 4 columns]

# %%
toko_df.to_csv("Toko di Jakarta.csv", index = False)

# %%
# kalo dah beda hari pas nge-run
toko_df.to_csv("Toko di Jakarta.csv", mode='a', header=False, index=False)

# %% [markdown]
# # Tujuan Wisata

# %%
i = 0
wisata_df = pd.DataFrame()

# %% [markdown]
# run bagian searchword, searchwordlist, sama scratch data list shop dulu

# %%
from selenium.common.exceptions import StaleElementReferenceException, ElementNotInteractableException
#Loading Selenium Webdriver 
driver= webdriver.Chrome()
wait = WebDriverWait(driver, 5)
 
#Opening Google maps 
driver.get("https://www.google.com/maps")
time.sleep(3)

category = ["Tujuan Wisata", "Wisata", "Taman Hiburan", "Hiburan"]

for index, row in df_jakarta_new.iterrows():
    try: 
        if (index >= i): 
            i = index
            wisata_df = scratch_data_list_shop(wisata_df, "Tujuan Wisata", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except StaleElementReferenceException:
        if (index >= i): 
            i = index
            wisata_df = scratch_data_list_shop(wisata_df, "Tujuan Wisata", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except NoSuchElementException: 
        continue
    except ElementNotInteractableException:
        pass
    # finally:
    #     searchbox=driver.find_element(By.ID, ('searchboxinput'))
    #     searchbox.clear() 
    #     continue

i = 0
# Out:
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,6(3.230)
# Berhasil
# 4,6(5.254)
# Berhasil
# 4,6(3.088)
# Berhasil
# 4,5(2.335)
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# 4,6(69.239)
# Berhasil
# 4,5(3.449)
# Berhasil
# 4,6(454)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,0(1)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# 5,0(9)
# Berhasil
# Berhasil
# 5,0(4)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,7(1.665)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# 4,6(289)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,8(30)
# Berhasil
# Berhasil
# 4,5(799)
# Berhasil
# 4,7(13)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# 4,6(16)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(4)
# Data Ditambahkan
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,6(16.465)
# Berhasil
# Berhasil
# 4,7(1.665)
# Berhasil
# 4,5(1.324)
# Berhasil
# Berhasil
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# 5,0(9)
# Berhasil
# Berhasil
# 4,7(17)
# Berhasil
# 4,8(30)
# Berhasil
# 4,6(8.433)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,6(289)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(9)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,5(32)
# Berhasil
# 4,0(1)
# Berhasil
# Berhasil
# Berhasil
# 4,7(17)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# 4,6(16)
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 4,6(16.465)
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# Berhasil
# Berhasil
# 4,7(1.665)
# Berhasil
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# 4,5(86)
# Berhasil
# Berhasil
# Berhasil
# 4,7(154)
# Berhasil
# Berhasil
# 4,8(30)
# Berhasil
# Berhasil
# 4,4(40)
# Berhasil
# Berhasil
# 4,7(17)
# Berhasil
# Berhasil
# 5,0(9)
# Berhasil
# Berhasil
# 4,6(3.307)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,6(72)
# Berhasil
# 4,6(16)
# Berhasil
# 4,7(1.665)
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# 4,7(7.450)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# Berhasil
# 4,7(197)
# Berhasil
# Berhasil
# Berhasil
# 4,5(799)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(9)
# Data Ditambahkan
# Berhasil
# Berhasil
# Berhasil
# 4,6(72)
# Berhasil
# 4,6(5.346)
# Berhasil
# Berhasil
# Berhasil
# 4,0(1)
# Berhasil
# 4,7(1.665)
# Berhasil
# Berhasil
# 4,6(289)
# Berhasil
# Berhasil
# 4,5(799)
# Berhasil
# Berhasil
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# 4,8(51)
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(4)
# Berhasil
# 4,8(30)
# Berhasil
# 5,0(1)
# Berhasil
# 5,0(1)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 5,0(1)
# Berhasil
# 4,6(5.346)
# Berhasil
# 4,5(1.324)
# Berhasil
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# 4,5(3.449)
# Berhasil
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,5(244)
# Berhasil
# 4,8(821)
# Berhasil
# Berhasil
# 4,8(558)
# Berhasil
# 4,6(8.433)
# Berhasil
# 4,7(141)
# Berhasil
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(1.324)
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,7(2.369)
# Berhasil
# Berhasil
# 4,8(558)
# Berhasil
# Berhasil
# 4,8(821)
# Berhasil
# Berhasil
# 4,7(17)
# Berhasil
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# 4,5(1.324)
# Berhasil
# 4,6(16.465)
# Berhasil
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# 4,8(821)
# Berhasil
# 4,5(244)
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,8(558)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,7(1.665)
# Berhasil
# 4,6(5.346)
# Berhasil
# 4,6(16.465)
# Berhasil
# Berhasil
# 4,5(1.324)
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# 4,5(3.449)
# Berhasil
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,5(244)
# Berhasil
# 4,8(558)
# Berhasil
# Berhasil
# 4,8(821)
# Berhasil
# 4,6(8.433)
# Berhasil
# 4,7(1.665)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,6(5.346)
# Data Ditambahkan
# Berhasil
# 4,7(4.974)
# Data Ditambahkan
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(891)
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,8(558)
# Berhasil
# Berhasil
# 4,8(68)
# Berhasil
# 4,8(821)
# Berhasil
# 4,4(37)
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(1.324)
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# Berhasil
# 4,5(244)
# Berhasil
# 4,5(891)
# Berhasil
# 4,6(3.088)
# Berhasil
# 4,5(3.449)
# Berhasil
# 4,7(2.369)
# Berhasil
# Berhasil
# 4,5(86)
# Berhasil
# 5,0(1)
# Berhasil
# 4,6(8.433)
# Berhasil
# 4,9(15)
# Berhasil
# 4,5(2.335)
# Berhasil
# 4,6(5.895)
# Berhasil
# 4,6(16.465)
# Berhasil
# Berhasil
# 4,5(1.324)
# Berhasil
# 4,6(5.346)
# Berhasil
# Berhasil
# 4,6(3.088)
# Berhasil
# 4,6(8.433)
# Berhasil
# 4,5(3.449)
# Berhasil
# 4,5(244)
# Berhasil
# 4,5(2.335)
# Berhasil
# 4,6(5.895)
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,5(86)
# Berhasil
# 4,6(4.903)
# Berhasil
# 4,5(891)
# Berhasil
# 4,7(141)
# Berhasil
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(1.324)
# Berhasil
# 4,6(69.239)
# Berhasil
# 4,6(3.088)
# Berhasil
# 4,6(5.346)
# Berhasil
# Berhasil
# 4,5(2.335)
# Berhasil
# 4,5(891)
# Berhasil
# 4,5(3.449)
# Berhasil
# 4,6(8.433)
# Berhasil
# 4,6(5.895)
# Berhasil
# 4,5(86)
# Berhasil
# 4,5(244)
# Berhasil
# 4,6(14)
# Berhasil
# 4,7(141)
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,4(7)
# Data Ditambahkan
# Berhasil
# 4,6(3.230)
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(1.324)
# Berhasil
# Berhasil
# Berhasil
# 4,6(69.239)
# Berhasil
# 4,6(3.088)
# Berhasil
# 4,5(3.449)
# Berhasil
# 4,5(2.335)
# Berhasil
# 4,6(8.433)
# Berhasil
# 4,5(86)
# Berhasil
# 4,6(5.346)
# Berhasil
# 4,6(5.895)
# Berhasil
# 4,7(141)
# Berhasil
# 4,5(244)
# Berhasil
# 4,7(2.369)
# Berhasil
# 4,5(891)
# Berhasil
# 4,6(14)
# Berhasil
# 5,0(1)
# Berhasil
# 4,6(16.465)
# Berhasil
# 4,5(1.324)
# Berhasil
# Berhasil
# 4,8(1.136)
# Berhasil
# Berhasil
# 4,6(5.346)
# Berhasil
# 4,6(278)
# Berhasil
# 4,5(86)
# Berhasil
# 4,7(10.036)
# Berhasil
# 4,6(69.239)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 16
#      14     if (index >= i):
#      15         i = index
# ---> 16         wisata_df = scratch_data_list_shop(wisata_df, "Tujuan Wisata", row["nama_kelurahan"], row["nama_kecamatan"], category)
#      17 except StaleElementReferenceException:
#      18     if (index >= i):
#
# Cell In[13], line 60, in scratch_data_list_shop(maps_df, jenis, kelurahan, kecamatan, kategori)
#      57         break
#      59 try:
# ---> 60     category = driver.find_element(By.CSS_SELECTOR, "[jsaction = 'pane.rating.category']").text
#      61 except NoSuchElementException:
#      62     continue
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
wisata_df
# Out:
#           Kelurahan          Kecamatan                          Nama  \
# 0       Penjaringan        PENJARINGAN                      Pohon RF
# 1       Penjaringan        PENJARINGAN  The Mangrove Paddling Center
# 2       Penjaringan        PENJARINGAN                   Rizik House
# 3       Kamal Muara        PENJARINGAN                Urban Farm PIK
# 4       Kamal Muara        PENJARINGAN         Meppo Kamal DJAVATRIP
# ..              ...                ...                           ...
# 81            Kapuk         CENGKARENG    Mural sepasang ondel ondel
# 82  Cengkareng Tim.         CENGKARENG                         M_BCT
# 83   Tj. Duren Sel.  GROGOL PETAMBURAN              Jakarta Aquarium
# 84   Tj. Duren Sel.  GROGOL PETAMBURAN                  Tribeca Park
# 85           Tangki         TAMAN SARI              Refleksi pandawa
#
#                                                Alamat
# 0   Alamat: VQJ4+98H, Jl. Mandara Permai, RT.1/RW....
# 1   Alamat: 8, RW.1, Kamal Muara, Penjaringan, Nor...
# 2   Alamat: VRP2+RC3, RT.19/RW.17, Penjaringan, Ke...
# 3   Alamat: Kawasan Pantai Maju, Jl. The Golf Isla...
# 4   Alamat: Jl. Pantai Kamal No.RT.8, RT.8/RW.1, K...
# ..                                                ...
# 81  Alamat: RT.4/RW.2, Kapuk, Kecamatan Cengkareng...
# 82  Alamat: Jl. Raya Daan Mogot No.12, RW.13, Ceng...
# 83  Alamat: Jl. Letjen S. Parman No.106, Tj. Duren...
# 84  Alamat: Letjen S. Parman No.28, RT.12/RW.6, Tj...
# 85  Alamat: Jl. Parking Lot Road Lokasari No.6, RW...
#
# [86 rows x 4 columns]

# %%
wisata_df[75:86].to_csv('Wisata di Jakarta.csv', mode = "a", header = False, index = False)

# %%
i = 99
# Out:
# 99

# %% [markdown]
# # Wisata di Jakarta pt 2

# %%
i = 171
wisata_df_2 = pd.DataFrame()

# %%
i = 100

# %%
from selenium.common.exceptions import StaleElementReferenceException, ElementNotInteractableException
#Loading Selenium Webdriver 
driver= webdriver.Chrome()
wait = WebDriverWait(driver, 5)
 
#Opening Google maps 
driver.get("https://www.google.com/maps")
time.sleep(3)

category = ["Tujuan", "Wisata", "Hiburan", "Taman", "Museum", "Bangunan", "Sejarah", "Bersejarah"]

for index, row in df_jakarta_new.iterrows():
    searchbox=driver.find_element(By.ID, ('searchboxinput'))
    searchbox.clear()
    try: 
        if (index >= i): 
            i = index
            wisata_df_2 = scratch_data_list_shop(wisata_df_2, "Tujuan Wisata", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except StaleElementReferenceException:
        if (index >= i): 
            searcbox.clear()
            i = index
            wisata_df_2 = scratch_data_list_shop(wisata_df_2, "Tujuan Wisata", row["nama_kelurahan"], row["nama_kecamatan"], category)
    except NoSuchElementException: 
        continue
    except ElementNotInteractableException:
        pass
    # finally:
    #     searchbox=driver.find_element(By.ID, ('searchboxinput'))
    #     searchbox.clear() 
    #     continue

i = 0
# Out:
# Berhasil
# 4,5(1.682)
# Berhasil
# 4,4(93)
# Berhasil
# 4,4(1.199)
# Berhasil
# 4,6(2.713)
# Berhasil
# 4,5(99.610)
# Berhasil
# Berhasil
# 4,5(58)
# Berhasil
# 4,4(666)
# Berhasil
# 4,5(3.488)
# Berhasil
# 4,6(144)
# Data Ditambahkan
# Berhasil
# 4,6(19)
# Berhasil
# 4,7(327)
# Berhasil
# 4,6(5.120)
# Berhasil
# 4,6(2.056)
# Berhasil
# 4,4(819)
# Berhasil
# Berhasil
# 4,3(433)
# Berhasil
# 4,3(2.223)
# Berhasil
# 4,2(4.272)
# Berhasil
# 4,5(896)
# Berhasil
# 4,4(8.154)
# Berhasil
# 4,5(8.852)
# Berhasil
# 4,2(77)
# Berhasil
# 4,5(2.882)
# Berhasil
# 4,4(1.111)
# Berhasil
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[21], line 14
#      12 for index, row in df_jakarta_new.iterrows():
#      13     searchbox=driver.find_element(By.ID, ('searchboxinput'))
# ---> 14     searchbox.clear()
#      15     try:
#      16         if (index >= i):
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:117, in WebElement.clear(self)
#     115 def clear(self) -> None:
#     116     """Clears the text if it's a text entry element."""
# --> 117     self._execute(Command.CLEAR_ELEMENT)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=114.0.5735.134)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00FCA813+48355]
# 	(No symbol) [0x00F5C4B1]
# 	(No symbol) [0x00E65220]
# 	(No symbol) [0x00E8B37A]
# 	(No symbol) [0x00EAA73C]
# 	(No symbol) [0x00E89A36]
# 	(No symbol) [0x00EAAA94]
# 	(No symbol) [0x00EBC922]
# 	(No symbol) [0x00EAA536]
# 	(No symbol) [0x00E882DC]
# 	(No symbol) [0x00E893DD]
# 	GetHandleVerifier [0x0122AABD+2539405]
# 	GetHandleVerifier [0x0126A78F+2800735]
# 	GetHandleVerifier [0x0126456C+2775612]
# 	GetHandleVerifier [0x010551E0+616112]
# 	(No symbol) [0x00F65F8C]
# 	(No symbol) [0x00F62328]
# 	(No symbol) [0x00F6240B]
# 	(No symbol) [0x00F54FF7]
# 	BaseThreadInitThunk [0x74DE7D59+25]
# 	RtlInitializeExceptionChain [0x7702B74B+107]
# 	RtlClearBits [0x7702B6CF+191]

# %%
wisata_df_2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
wisata_df_2[16:29].to_csv("Wisata di Jakarta versi Lengkap.csv", mode = "a", header = False)

# %%
print(i)
# Out:
# 171

# %%
# # Set the maximum time to wait for new data to load
# wait = WebDriverWait(driver, 5)

# # Specify a locator for an element that appears after scrolling and new data is loaded
# locator = (By.XPATH, "//*[@role='article']")

# # Function to scroll to the bottom of the page
# def scroll_to_bottom():
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# # Function to check if new data is loaded
# def is_new_data_loaded():
#     try:
#         wait.until(EC.visibility_of_element_located(locator))
#         return True
#     except:
#         return False

# # Scroll and extract data
# data = []

# while True:
#     # Scroll to the bottom of the page
#     scroll_to_bottom()
    
#     # Wait for new data to load
#     if is_new_data_loaded():
#         # Extract the data from the page
#         data_elements = driver.find_elements(By.XPATH, "//*[@role='article']")
#         for element in data_elements:
#             data.append(element.text)
#     else:
#         # No more data is loaded, exit the loop
#         break

# %%
# # Manually scroll through the page to load results
# scroll_pause_time = 1  # Adjust the pause time between scrolls as needed
# scroll_count = 10  # Adjust the number of scrolls to load more results as needed

# for _ in range(scroll_count):
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#     time.sleep(scroll_pause_time)

# %%
# scroll_container = driver.find_element(By.CSS_SELECTOR, "[attribute_name*='::-webkit-scrollbar']")
# scrollable_height = driver.execute_script("return arguments[0].scrollHeight", scroll_container)
# current_scroll_position = 0
# print(scrollable_height)

# while current_scroll_position < scrollable_height:
#     # Scroll to the bottom of the container
#     driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scroll_container)
#     time.sleep(1)  # Wait for the new results to load
#     current_scroll_position = scrollable_height
#     scrollable_height = driver.execute_script("return arguments[0].scrollHeight", scroll_container)

# %%
    # driver.close()
    # adress= entry.find_element(By.CLASS_NAME, 'section-result-location').text
    # phone = entry.find_element(By.CLASS_NAME, 'section-result-hours-phone-container').text.split(' · ')[-1]
    # print(name)
    # try:
    #     webcontainer= entry.find_element(By.CLASS_NAME, 'section-result-action-container')
    #     website=entry.find_element(By.TAG_NAME, 'a').get_attribute("href")
    # except NoSuchElementException:
    #     website="No website could be found"
    # print (name)
    # print (website)
       
 
    #Try/except  to write the extracted info in the Excel file pass if doessn't exist 
    # try:
    #     maps_df.append(pd.Series([location,name,adress,phone,website]))
    # except IndexError:
    #     pass
# Out:
# Starbucks DT Hayam Wuruk
# Alamat: Jl. Hayam Wuruk No.8, RT.6/RW.2, Kb. Klp., Kecamatan Gambir, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10120
# Starbucks
# Alamat: RT.1/RW.10, Kramat Pela, Kec. Kby. Baru, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12130
# Starbucks
# Alamat: Jl. M.H. Thamrin No.9, RT.2/RW.1, Kb. Sirih, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10340
# Starbucks
# Alamat: Jl. Letjen M.T. Haryono No.9, RT.11/RW.5, Tebet Bar., Jakarta, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12810
# Starbucks Cik Ditiro
# Alamat: Jl. Teuku Cik Ditiro No.33, RW.5, Menteng, Kec. Menteng, Kota Jakarta Pusat, Daerah Khusus Ibukota Jakarta 10310
# Starbucks
# Alamat: Cyber 2, Lantai GF, Blok X-5 Kav 1-2, Jl. H. R. Rasuna Said, RT.7/RW.2, Kuningan, Kuningan Tim., Kecamatan Setiabudi, Kota Jakarta Selatan, Daerah Khusus Ibukota Jakarta 12950
# Starbucks Plaza Indonesia Lv 4
# Alamat: M.H., Jl. K.H. Wahid Hasyim No.15, RT.7/RW.5, Gondangdia, Menteng, Central Jakarta City, Jakarta 10350
